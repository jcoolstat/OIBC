# %%
from nixtla import NixtlaClient
import pandas as pd
import requests

# %%
# 데이터 불러오기
df_1 = pd.read_csv("data/갱신시킬데이터/df_1_11_15_00까지.csv")
df_2 = pd.read_csv("data/갱신시킬데이터/df_2_11_14_00까지.csv")
df_3 = pd.read_csv("data/갱신시킬데이터/df_3_11_14_00까지.csv")
df_price = pd.read_csv("data/갱신시킬데이터/df_4_11_15_00까지.csv")

display(df_1.tail())
display(df_2.tail())
display(df_3.tail())
display(df_price.tail())
# Out:
#         location                   ts     temp  real_feel_temp  wet_bulb_temp  \
# 57910  Sangmo-ri  2024-11-14 20:00:00  20.5556         18.8889        17.7778
# 57911  Sangmo-ri  2024-11-14 21:00:00  20.5556         18.8889        17.7778
# 57912  Sangmo-ri  2024-11-14 22:00:00  20.0000         18.8889        17.7778
# 57913  Sangmo-ri  2024-11-14 23:00:00  20.5556         18.3333        18.3333
# 57914  Sangmo-ri  2024-11-15 00:00:00  20.5556         17.2222        18.3333
#
#        dew_point  wind_dir  wind_spd  wind_gust_spd  rel_hum  ...  uv_idx  \
# 57910    16.1111      99.0   14.8060        22.2089     75.0  ...     0.0
# 57911    16.6667     102.0   16.7372        22.2089     77.0  ...     0.0
# 57912    16.6667     105.0   16.7372        20.4387     79.0  ...     0.0
# 57913    16.6667     110.0   18.5075        20.4387     79.0  ...     0.0
# 57914    16.6667     118.0   18.5075        20.4387     80.0  ...     0.0
#
# ...

# %%
# 현재수요, 신재생 발전량 합치기
df = df_3.merge(df_2, on = 'ts', how = 'inner')
df.head()
# Out:
#                     ts  현재 수요(kW)  신재생 발전량 총합(kW)
# 0  2024-03-02 01:00:00   848000.0        201763.0
# 1  2024-03-02 02:00:00   814000.0        185359.0
# 2  2024-03-02 03:00:00   800000.0        158201.0
# 3  2024-03-02 04:00:00   784000.0        147329.0
# 4  2024-03-02 05:00:00   788000.0        136992.0

# %%
# df_1 평균내기
df_1 = df_1.groupby('ts', sort = False)[['temp', 'real_feel_temp', 'wet_bulb_temp',
       'dew_point', 'wind_dir', 'wind_spd', 'wind_gust_spd', 'rel_hum', 'vis',
       'ceiling', 'uv_idx', 'precip_prob', 'rain_prob', 'snow_prob',
       'ice_prob', 'total_liq', 'rain', 'snow', 'ice', 'cld_cvr']].mean().reset_index()

# %%
# date 매일 수정
date = '2024-11-14'
weather_forecast = requests.get(f'https://research-api.solarkim.com/data/cmpt-2024/weather-forecast/{date}', headers={
                            'Authorization': f'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJMQk4zUEw5UFZ5bU1HQ3RRb2piVmVNIiwiaWF0IjoxNzMwMDgxMTA5LCJleHAiOjE3MzE1OTY0MDAsInR5cGUiOiJhcGlfa2V5In0.midMda3q9Mpm7Ou3FUCjWAkWOpb_50eZPq13U-667OU'
                        }).json()
print(weather_forecast)
# Out:
# {'weather_forecast_1': [{'base_ts': 1731549600, 'ts': 1731596400, 'temp': 20.5556, 'real_feel_temp': 18.8889, 'wet_bulb_temp': 17.7778, 'dew_point': 16.1111, 'wind_spd': 18.5075, 'wind_dir': 122.0, 'wind_gust_spd': 20.4387, 'rel_hum': 75.0, 'vis': 8.04672, 'ceiling': 579.12, 'uv_idx': 0.0, 'precip_prob': 43.0, 'rain_prob': 43.0, 'snow_prob': 0.0, 'ice_prob': 0.0, 'total_liq': 0.0, 'rain': 0.0, 'snow': 0.0, 'ice': 0.0, 'cld_cvr': 99.0, 'location': 'Ilgwa-ri'}, {'base_ts': 1731549600, 'ts': 1731600000, 'temp': 20.5556, 'real_feel_temp': 18.8889, 'wet_bulb_temp': 17.7778, 'dew_point': 16.6667, 'wind_spd': 18.5075, 'wind_dir': 141.0, 'wind_gust_spd': 20.4387, 'rel_hum': 78.0, 'vis': 8.04672, 'ceiling': 579.12, 'uv_idx': 0.0, 'precip_prob': 20.0, 'rain_prob': 20.0, 'snow_prob': 0.0, 'ice_prob': 0.0, 'total_liq': 0.0, 'rain': 0.0, 'snow': 0.0, 'ice': 0.0, 'cld_cvr': 96.0, 'location': 'Ilgwa-ri'}, {'base_ts': 1731549600, 'ts': 1731603600, 'temp': 19.4444, 'real_feel_temp': 17.7778, 'wet_bul
# ...

# %%
weather_forecast_1 = weather_forecast['weather_forecast_1']
weather_forecast_1 = pd.DataFrame(weather_forecast_1)

# ts를 datetime 형식으로 변경하고 9시간 더하기
weather_forecast_1['ts'] = pd.to_datetime(weather_forecast_1['ts'], unit = 's', errors = 'coerce') + pd.Timedelta(hours = 9)

# 확인
weather_forecast_1
# Out:
#         base_ts                  ts     temp  real_feel_temp  wet_bulb_temp  \
# 0    1731549600 2024-11-15 00:00:00  20.5556         18.8889        17.7778
# 1    1731549600 2024-11-15 01:00:00  20.5556         18.8889        17.7778
# 2    1731549600 2024-11-15 02:00:00  19.4444         17.7778        17.7778
# 3    1731549600 2024-11-15 03:00:00  20.0000         18.3333        18.3333
# 4    1731549600 2024-11-15 04:00:00  20.0000         18.8889        18.3333
# ..          ...                 ...      ...             ...            ...
# 120  1731549600 2024-11-15 20:00:00  20.5556         19.4444        19.4444
# 121  1731549600 2024-11-15 21:00:00  20.5556         20.5556        19.4444
# 122  1731549600 2024-11-15 22:00:00  20.5556         18.8889        19.4444
# 123  1731549600 2024-11-15 23:00:00  20.5556         20.0000        18.8889
# 124  1731549600 2024-11-16 00:00:00  20.5556         20.0000        18.8889
#
# ...

# %%
# df_1 평균내기
weather_forecast_1 = weather_forecast_1.groupby('ts', sort = False)[['temp', 'real_feel_temp', 'wet_bulb_temp',
       'dew_point', 'wind_dir', 'wind_spd', 'wind_gust_spd', 'rel_hum', 'vis',
       'ceiling', 'uv_idx', 'precip_prob', 'rain_prob', 'snow_prob',
       'ice_prob', 'total_liq', 'rain', 'snow', 'ice', 'cld_cvr']].mean().reset_index()

# weather_forecast_1의 컬럼 위치를 df_1에 맞추기
weather_forecast_1 = weather_forecast_1[['ts', 'temp', 'real_feel_temp', 'wet_bulb_temp',
       'dew_point', 'wind_dir', 'wind_spd', 'wind_gust_spd', 'rel_hum', 'vis',
       'ceiling', 'uv_idx', 'precip_prob', 'rain_prob', 'snow_prob',
       'ice_prob', 'total_liq', 'rain', 'snow', 'ice', 'cld_cvr']]

# weater_forecast_1에서 ts가 2024-11-06 00:00:00인 행 삭제 ( 매일 달라진다  ) - 첫 행 제거하면 됨
weather_forecast_1 = weather_forecast_1[weather_forecast_1['ts'] != '2024-11-15 00:00:00']

# df_1 밑에 weather_forecast_1 붙이기
df_1 = pd.concat([df_1, weather_forecast_1], ignore_index=True)

# 확인
df_1
# Out:
#                        ts       temp  real_feel_temp  wet_bulb_temp  \
# 0     2024-03-02 01:00:00   1.851852       -4.506173      -0.432099
# 1     2024-03-02 02:00:00   1.790123       -5.061728      -0.370370
# 2     2024-03-02 03:00:00   1.604940       -5.308640      -0.370370
# 3     2024-03-02 04:00:00   1.851852       -4.876541      -0.308642
# 4     2024-03-02 05:00:00   1.913581       -4.629628      -0.308642
# ...                   ...        ...             ...            ...
# 6211  2024-11-15 20:00:00  20.666700       20.111100      19.444420
# 6212  2024-11-15 21:00:00  20.444480       19.666660      19.222200
# 6213  2024-11-15 22:00:00  20.333360       19.555540      19.222200
# 6214  2024-11-15 23:00:00  20.444480       20.000000      19.111100
# 6215  2024-11-16 00:00:00  20.333360       19.888880      19.000000
#
#       dew_point    wind_dir   wind_spd  wind_gust_spd    rel_hum        vis  \
# ...

# %%
# df_1에서 뒤에 48개를 제외한 데이터를 df_1_for_train 변수에 저장
df_1_for_train = df_1.iloc[:-48]

# df_1에서 뒤에 48개를 for_predict 변수에 저장
for_predict = df_1.tail(48)

display(df_1_for_train.head())
display(for_predict.head())
# Out:
#                     ts      temp  real_feel_temp  wet_bulb_temp  dew_point  \
# 0  2024-03-02 01:00:00  1.851852       -4.506173      -0.432099  -4.135800
# 1  2024-03-02 02:00:00  1.790123       -5.061728      -0.370370  -3.950616
# 2  2024-03-02 03:00:00  1.604940       -5.308640      -0.370370  -3.888887
# 3  2024-03-02 04:00:00  1.851852       -4.876541      -0.308642  -3.950616
# 4  2024-03-02 05:00:00  1.913581       -4.629628      -0.308642  -4.012346
#
#      wind_dir   wind_spd  wind_gust_spd    rel_hum        vis  ...  uv_idx  \
# 0  335.000000  22.048022      50.640711  64.333333  15.378140  ...     0.0
# 1  334.444444  22.656000      51.481144  66.333333  14.392882  ...     0.0
# 2  333.777778  23.263967      51.463267  67.333333  15.195758  ...     0.0
# 3  333.888889  23.871922      50.837400  66.444444  15.825200  ...     0.0
# 4  334.111111  23.478533      50.229433  65.111111  15.733989  ...     0.0
#
# ...

# %% [markdown]
# <hr>

# %%
nixtla_client = NixtlaClient(api_key ='nixak-A5WgOZ0TrXNQp4GXx6sxZpKSF7kPJds6FsUgzr7V9gvSbKFyyzaDNj11btknO3VKK5Nokap1sB1OdDlb')

nixtla_client.validate_api_key()
# Out:
# True

# %%
full_data = df.merge(df_1_for_train, on = 'ts', how = 'inner')
full_data
# Out:
#                        ts  현재 수요(kW)  신재생 발전량 총합(kW)       temp  \
# 0     2024-03-02 01:00:00   848000.0        201763.0   1.851852
# 1     2024-03-02 02:00:00   814000.0        185359.0   1.790123
# 2     2024-03-02 03:00:00   800000.0        158201.0   1.604940
# 3     2024-03-02 04:00:00   784000.0        147329.0   1.851852
# 4     2024-03-02 05:00:00   788000.0        136992.0   1.913581
# ...                   ...        ...             ...        ...
# 6163  2024-11-13 20:00:00   706000.0         83315.8  17.654322
# 6164  2024-11-13 21:00:00   679000.0         58584.8  17.283956
# 6165  2024-11-13 22:00:00   652000.0         44252.3  16.851856
# 6166  2024-11-13 23:00:00   634000.0         46032.4  16.728411
# 6167  2024-11-14 00:00:00   585000.0         45179.4  16.543222
#
#       real_feel_temp  wet_bulb_temp  dew_point    wind_dir   wind_spd  \
# 0          -4.506173      -0.432099  -4.135800  335.000000  22.048022
# ...

# %%
# 현재 수요만 남기기
df_required_power = full_data.drop(columns = ['신재생 발전량 총합(kW)'])

# 신재생만 남기기
df_renewable_power = full_data.drop(columns = ['현재 수요(kW)'])

# %%
# 현재 수요 예측
timegpt_fcst_ex_vars_df_1 = nixtla_client.forecast(df=df_required_power, 
                                                 X_df=for_predict, 
                                                 h=48, 
                                                 time_col = 'ts',
                                                 target_col = '현재 수요(kW)',
                                                 freq = '1h',
                                                 level=[80, 90])
required_power_fcst = timegpt_fcst_ex_vars_df_1[['ts', 'TimeGPT']].rename(columns = {'TimeGPT': '현재 수요(kW)'})
required_power_fcst
# Out:
# INFO:nixtla.nixtla_client:Validating inputs...
# INFO:nixtla.nixtla_client:Querying model metadata...
# WARNING:nixtla.nixtla_client:The specified horizon "h" exceeds the model horizon. This may lead to less accurate forecasts. Please consider using a smaller horizon.
# INFO:nixtla.nixtla_client:Preprocessing dataframes...
# INFO:nixtla.nixtla_client:Using future exogenous features: ['temp', 'real_feel_temp', 'wet_bulb_temp', 'dew_point', 'wind_dir', 'wind_spd', 'wind_gust_spd', 'rel_hum', 'vis', 'ceiling', 'uv_idx', 'precip_prob', 'rain_prob', 'snow_prob', 'ice_prob', 'total_liq', 'rain', 'snow', 'ice', 'cld_cvr']
# INFO:nixtla.nixtla_client:Calling Forecast Endpoint...
#                     ts  현재 수요(kW)
# 0  2024-11-14 01:00:00  570662.00
# 1  2024-11-14 02:00:00  555100.40
# 2  2024-11-14 03:00:00  556691.20
# 3  2024-11-14 04:00:00  540695.75
# 4  2024-11-14 05:00:00  542892.80
# 5  2024-11-14 06:00:00  539769.00
# 6  2024-11-14 07:00:00  556438.90
# ...

# %%
# 신재생 발전량 예측
timegpt_fcst_ex_vars_df_2 = nixtla_client.forecast(df=df_renewable_power, 
                                                 X_df=for_predict, 
                                                 h=48, 
                                                 time_col = 'ts',
                                                 target_col = '신재생 발전량 총합(kW)',
                                                 freq = '1h',
                                                 level=[80, 90])
renewable = timegpt_fcst_ex_vars_df_2[['ts', 'TimeGPT']].rename(columns = {'TimeGPT': '신재생 발전량 총합(kW)'})
renewable
# Out:
# INFO:nixtla.nixtla_client:Validating inputs...
# WARNING:nixtla.nixtla_client:The specified horizon "h" exceeds the model horizon. This may lead to less accurate forecasts. Please consider using a smaller horizon.
# INFO:nixtla.nixtla_client:Preprocessing dataframes...
# INFO:nixtla.nixtla_client:Using future exogenous features: ['temp', 'real_feel_temp', 'wet_bulb_temp', 'dew_point', 'wind_dir', 'wind_spd', 'wind_gust_spd', 'rel_hum', 'vis', 'ceiling', 'uv_idx', 'precip_prob', 'rain_prob', 'snow_prob', 'ice_prob', 'total_liq', 'rain', 'snow', 'ice', 'cld_cvr']
# INFO:nixtla.nixtla_client:Calling Forecast Endpoint...
#                     ts  신재생 발전량 총합(kW)
# 0  2024-11-14 01:00:00       40026.700
# 1  2024-11-14 02:00:00       43736.145
# 2  2024-11-14 03:00:00       45226.890
# 3  2024-11-14 04:00:00       41141.680
# 4  2024-11-14 05:00:00       40456.082
# 5  2024-11-14 06:00:00       47023.004
# 6  2024-11-14 07:00:00       43952.734
# 7  2024-11-14 08:00:00       37067.355
# ...

# %%
data_fcst = required_power_fcst.merge(renewable, on = 'ts', how = 'inner')
data_fcst
# Out:
#                     ts  현재 수요(kW)  신재생 발전량 총합(kW)
# 0  2024-11-14 01:00:00  570662.00       40026.700
# 1  2024-11-14 02:00:00  555100.40       43736.145
# 2  2024-11-14 03:00:00  556691.20       45226.890
# 3  2024-11-14 04:00:00  540695.75       41141.680
# 4  2024-11-14 05:00:00  542892.80       40456.082
# 5  2024-11-14 06:00:00  539769.00       47023.004
# 6  2024-11-14 07:00:00  556438.90       43952.734
# 7  2024-11-14 08:00:00  592275.10       37067.355
# 8  2024-11-14 09:00:00  598672.10      155479.060
# 9  2024-11-14 10:00:00  589396.70      206756.940
# 10 2024-11-14 11:00:00  587915.75      203070.190
# 11 2024-11-14 12:00:00  599552.90      191351.810
# 12 2024-11-14 13:00:00  600152.94      222719.030
# 13 2024-11-14 14:00:00  609497.40      223708.050
# 14 2024-11-14 15:00:00  630010.06      173972.530
# 15 2024-11-14 16:00:00  691531.10      116539.440
# 16 2024-11-14 17:00:00  750125.50       53575.785
# 17 2024-11-14 18:00:00  766167.60       29014.426
# ...

# %%
# head(24)를 떼와서 2B-A
df_train = data_fcst.head(24)
df_train['2B-A'] = 2*df_train['신재생 발전량 총합(kW)'] - df_train['현재 수요(kW)']

# 2B-A만 가져오기
df_train = df_train[['ts', '2B-A']]
df_train
# Out:
# /var/folders/_l/xyl0ncd93sl5xc6z9vcxbp2w0000gn/T/ipykernel_1461/541042810.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['2B-A'] = 2*df_train['신재생 발전량 총합(kW)'] - df_train['현재 수요(kW)']
#                     ts        2B-A
# 0  2024-11-14 01:00:00 -490608.600
# 1  2024-11-14 02:00:00 -467628.110
# 2  2024-11-14 03:00:00 -466237.420
# 3  2024-11-14 04:00:00 -458412.390
# 4  2024-11-14 05:00:00 -461980.636
# 5  2024-11-14 06:00:00 -445722.992
# 6  2024-11-14 07:00:00 -468533.432
# 7  2024-11-14 08:00:00 -518140.390
# 8  2024-11-14 09:00:00 -287713.980
# 9  2024-11-14 10:00:00 -175882.820
# 10 2024-11-14 11:00:00 -181775.370
# 11 2024-11-14 12:00:00 -216849.280
# 12 2024-11-14 13:00:00 -154714.880
# ...

# %%
full_data['2B-A'] = full_data['신재생 발전량 총합(kW)']*2 - full_data['현재 수요(kW)']
tmp = full_data[['ts', '2B-A']]
tmp
# Out:
#                        ts      2B-A
# 0     2024-03-02 01:00:00 -444474.0
# 1     2024-03-02 02:00:00 -443282.0
# 2     2024-03-02 03:00:00 -483598.0
# 3     2024-03-02 04:00:00 -489342.0
# 4     2024-03-02 05:00:00 -514016.0
# ...                   ...       ...
# 6163  2024-11-13 20:00:00 -539368.4
# 6164  2024-11-13 21:00:00 -561830.4
# 6165  2024-11-13 22:00:00 -563495.4
# 6166  2024-11-13 23:00:00 -541935.2
# 6167  2024-11-14 00:00:00 -494641.2
#
# [6168 rows x 2 columns]

# %%
df_train = pd.concat([tmp, df_train], ignore_index = True)
df_train
# Out:
#                        ts        2B-A
# 0     2024-03-02 01:00:00 -444474.000
# 1     2024-03-02 02:00:00 -443282.000
# 2     2024-03-02 03:00:00 -483598.000
# 3     2024-03-02 04:00:00 -489342.000
# 4     2024-03-02 05:00:00 -514016.000
# ...                   ...         ...
# 6187  2024-11-14 20:00:00 -594137.234
# 6188  2024-11-14 21:00:00 -586993.896
# 6189  2024-11-14 22:00:00 -599729.446
# 6190  2024-11-14 23:00:00 -551174.860
# 6191  2024-11-15 00:00:00 -451336.820
#
# [6192 rows x 2 columns]

# %%
# ts를 char로 변경
df_train['ts'] = df_train['ts'].astype(str)
df_price['ts'] = df_price['ts'].astype(str)

# %%
final_train = df_price.merge(df_train, on = 'ts', how = 'left')
final_train
# Out:
#                        ts  하루전가격(원/kWh)        2B-A
# 0     2024-03-02 01:00:00        138.50 -444474.000
# 1     2024-03-02 02:00:00         99.48 -443282.000
# 2     2024-03-02 03:00:00         95.38 -483598.000
# 3     2024-03-02 04:00:00         91.24 -489342.000
# 4     2024-03-02 05:00:00         91.24 -514016.000
# ...                   ...           ...         ...
# 6187  2024-11-14 20:00:00        116.98 -594137.234
# 6188  2024-11-14 21:00:00        126.24 -586993.896
# 6189  2024-11-14 22:00:00        125.50 -599729.446
# 6190  2024-11-14 23:00:00        106.52 -551174.860
# 6191  2024-11-15 00:00:00        105.55 -451336.820
#
# [6192 rows x 3 columns]

# %%
# datetime 형식으로 변경
final_train['ts'] = pd.to_datetime(final_train['ts'])
final_train
# Out:
#                       ts  하루전가격(원/kWh)        2B-A
# 0    2024-03-02 01:00:00        138.50 -444474.000
# 1    2024-03-02 02:00:00         99.48 -443282.000
# 2    2024-03-02 03:00:00         95.38 -483598.000
# 3    2024-03-02 04:00:00         91.24 -489342.000
# 4    2024-03-02 05:00:00         91.24 -514016.000
# ...                  ...           ...         ...
# 6187 2024-11-14 20:00:00        116.98 -594137.234
# 6188 2024-11-14 21:00:00        126.24 -586993.896
# 6189 2024-11-14 22:00:00        125.50 -599729.446
# 6190 2024-11-14 23:00:00        106.52 -551174.860
# 6191 2024-11-15 00:00:00        105.55 -451336.820
#
# [6192 rows x 3 columns]

# %%
# 예측에 사용될 데이터
X_df = data_fcst.tail(24)
X_df
# Out:
#                     ts  현재 수요(kW)  신재생 발전량 총합(kW)
# 24 2024-11-15 01:00:00  618476.90       77954.530
# 25 2024-11-15 02:00:00  558466.10       80510.820
# 26 2024-11-15 03:00:00  569482.94       53788.312
# 27 2024-11-15 04:00:00  584772.06       68462.340
# 28 2024-11-15 05:00:00  598124.06       68139.875
# 29 2024-11-15 06:00:00  605912.70       83777.050
# 30 2024-11-15 07:00:00  628791.56       68289.805
# 31 2024-11-15 08:00:00  638986.80       62966.016
# 32 2024-11-15 09:00:00  663394.90      115811.860
# 33 2024-11-15 10:00:00  669287.44      149413.800
# 34 2024-11-15 11:00:00  681977.10      165839.720
# 35 2024-11-15 12:00:00  678196.00      134368.840
# 36 2024-11-15 13:00:00  685399.56      138904.280
# 37 2024-11-15 14:00:00  681361.25      118647.484
# 38 2024-11-15 15:00:00  667787.25      111716.914
# 39 2024-11-15 16:00:00  692244.60       86925.625
# 40 2024-11-15 17:00:00  760765.10       79435.860
# 41 2024-11-15 18:00:00  791509.50       69115.550
# ...

# %%
# 2B-A 만들기
X_df['2B-A'] = 2*X_df['신재생 발전량 총합(kW)'] - X_df['현재 수요(kW)']

# 2B-A만 가져오기
X_df = X_df[['ts', '2B-A']]

X_df
# Out:
# /var/folders/_l/xyl0ncd93sl5xc6z9vcxbp2w0000gn/T/ipykernel_1461/1454268997.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_df['2B-A'] = 2*X_df['신재생 발전량 총합(kW)'] - X_df['현재 수요(kW)']
#                     ts        2B-A
# 24 2024-11-15 01:00:00 -462567.840
# 25 2024-11-15 02:00:00 -397444.460
# 26 2024-11-15 03:00:00 -461906.316
# 27 2024-11-15 04:00:00 -447847.380
# 28 2024-11-15 05:00:00 -461844.310
# 29 2024-11-15 06:00:00 -438358.600
# 30 2024-11-15 07:00:00 -492211.950
# 31 2024-11-15 08:00:00 -513054.768
# 32 2024-11-15 09:00:00 -431771.180
# 33 2024-11-15 10:00:00 -370459.840
# 34 2024-11-15 11:00:00 -350297.660
# 35 2024-11-15 12:00:00 -409458.320
# 36 2024-11-15 13:00:00 -407591.000
# 37 2024-11-15 14:00:00 -444066.282
# ...

# %%
timegpt_fcst_ex_vars_df_3 = nixtla_client.forecast(df=final_train, 
                                                 X_df=X_df, 
                                                 h=24, 
                                                 time_col = 'ts',
                                                 target_col = '하루전가격(원/kWh)',
                                                 freq = '1h',
                                                 level=[80, 90])

result = timegpt_fcst_ex_vars_df_3['TimeGPT'].tolist()
# Out:
# INFO:nixtla.nixtla_client:Validating inputs...
# INFO:nixtla.nixtla_client:Preprocessing dataframes...
# INFO:nixtla.nixtla_client:Using future exogenous features: ['2B-A']
# INFO:nixtla.nixtla_client:Calling Forecast Endpoint...

# %%
print(result)
# Out:
# [99.21614, 94.43634, 92.54863, 90.70758, 95.513084, 103.06137, 122.58008, 129.66217, 146.42505, 151.16898, 152.92455, 157.81625, 144.14447, 144.81412, 139.24799, 134.00558, 136.70193, 134.98169, 137.82329, 133.28954, 125.514755, 113.87694, 105.652695, 113.8765]

# %%
import json
import requests

result = {
    'submit_result' : result
}
success = requests.post('https://research-api.solarkim.com/submissions/cmpt-2024',
                    data=json.dumps(result),
                    headers={
                        'Authorization': f'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJMQk4zUEw5UFZ5bU1HQ3RRb2piVmVNIiwiaWF0IjoxNzMwMDgxMTA5LCJleHAiOjE3MzE1OTY0MDAsInR5cGUiOiJhcGlfa2V5In0.midMda3q9Mpm7Ou3FUCjWAkWOpb_50eZPq13U-667OU'
                    }).json()
print(success)
# Out:
# True
