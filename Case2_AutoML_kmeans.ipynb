# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('df_cust_financial_with_cluster.csv')
df = df.drop(columns=["id","join_key",
                      "join_key_2",'new_col'])
df
# Out:
#          age  asset_avg  debt_avg  card_uses    BIS  distance_km  clusters  \
# 0       27.5        5.5         0        0.0  100.0   148.974285        18
# 1       27.5      350.0         0        0.0  100.0   141.374637         2
# 2       27.5        0.5         0        0.0  100.0   138.586812         2
# 3       27.5     2000.0         0        0.0  100.0   140.175239         7
# 4       27.5        5.5         0       40.0  100.0   141.374637         2
# ...      ...        ...       ...        ...    ...          ...       ...
# 188928  52.5        0.5         0        0.0  100.0   148.974285        32
# 188929  52.5        0.5         0        0.0  100.0   140.314850        21
# 188930  22.5        0.5         0        0.0  100.0   145.434091        29
# 188931  57.5        0.5         0        0.0  100.0   140.314850        21
# 188932  52.5     2000.0         0       15.0  100.0   145.434091        24
#
#         gender_M
# 0              1
# 1              1
# ...

# %%
import pycaret
from pycaret.classification import *

reg2 = setup(data = df, target = 'clusters',train_size=0.8, session_id=123, use_gpu=True)
# Out:
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4070 Ti SUPER, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 16 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Warning] GPU acceleration is disabled because no non-trivial dense features can be found
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# ...

# %%
models()
# Out:
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4070 Ti SUPER, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 16 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Warning] GPU acceleration is disabled because no non-trivial dense features can be found
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# ...

# %%
# clf = create_model('xgboost')

# %%
best_classification_model = compare_models(exclude = ['ada','lr','gbc','svm'],sort='Recall', n_select=3)
# Out:
# <style type="text/css">
# #T_6b061 th {
#   text-align: left;
# }
# ...

# %%
# plot_model(clf, plot='feature')

# %%
tuned_model=[tune_model(i) for i in best_classification_model]
# Out:
# <style type="text/css">
# #T_b28ff_row10_col0, #T_b28ff_row10_col1, #T_b28ff_row10_col2, #T_b28ff_row10_col3, #T_b28ff_row10_col4, #T_b28ff_row10_col5, #T_b28ff_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_b28ff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b28ff_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_b28ff_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_b28ff_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_b28ff_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_b28ff_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_b28ff_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_b28ff_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
blended_cls=blend_models(estimator_list=tuned_model,fold=4,optimize='Recall')
# Out:
# <style type="text/css">
# #T_c0f65_row4_col0, #T_c0f65_row4_col1, #T_c0f65_row4_col2, #T_c0f65_row4_col3, #T_c0f65_row4_col4, #T_c0f65_row4_col5, #T_c0f65_row4_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_c0f65">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0f65_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_c0f65_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_c0f65_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_c0f65_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_c0f65_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_c0f65_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_c0f65_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
final_model_cls = finalize_model(blended_cls)

# %%
test_df = pd.read_csv('df_cust_non_financial.csv')
prediction=predict_model(final_model_cls,data=test_df)

# %%
prediction.head()
# Out:
#    Unnamed: 0   age  asset_avg  debt_avg  card_uses  distance_km    BIS  \
# 0           0  27.5        0.5         0        0.0   136.026749  100.0
# 1           1  27.5        0.5         0        0.0   136.026749  100.0
# 2           2  27.5        0.5         0        0.0   136.026749  100.0
# 3           3  27.5        0.5         0        0.0   136.026749  100.0
# 4           4  27.5        0.5         0        0.0   136.026749  100.0
#
#    gender_M  prediction_label  prediction_score
# 0     False                29             0.997
# 1     False                29             0.997
# 2     False                29             0.997
# 3     False                29             0.997
# 4     False                29             0.997

# %%
test_df["clusters"]=prediction["prediction_label"]
test_df
# Out:
#         Unnamed: 0   age  asset_avg  debt_avg  card_uses  distance_km  \
# 0                0  27.5        0.5         0        0.0   136.026742
# 1                1  27.5        0.5         0        0.0   136.026742
# 2                2  27.5        0.5         0        0.0   136.026742
# 3                3  27.5        0.5         0        0.0   136.026742
# 4                4  27.5        0.5         0        0.0   136.026742
# ...            ...   ...        ...       ...        ...          ...
# 464067      464067  62.5     3000.0     30000      200.0   148.974285
# 464068      464068  67.5     3000.0     30000      200.0   148.974285
# 464069      464069  67.5     3000.0     30000      200.0   148.974285
# 464070      464070  67.5     3000.0     30000      200.0   148.974285
# 464071      464071  70.0     3000.0     30000      200.0   148.974285
#
#                BIS  gender_M  clusters
# 0       100.000000     False        29
# 1       100.000000     False        29
# ...

# %%
test_df.to_csv('df_cust_non_financial_AUTOML_PREIDICTED.csv', index = False)
