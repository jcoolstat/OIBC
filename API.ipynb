# %%
import requests

API_KEY = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJRRjVkcjJXQ3RhUjhHRFE2b29pV0hpIiwiaWF0IjoxNzMwMDgxMTA5LCJleHAiOjE3MzE1OTY0MDAsInR5cGUiOiJhcGlfa2V5In0.ZQkH4OeUKWiupEBMjHzQQRi97sVHZ-OU-j-ye_qpHz0'

# %% [markdown]
# #### 1. 기상 실측 조회

# %%
date = '2024-10-23'

actual_weather = requests.get(f'https://research-api.solarkim.com/data/cmpt-2024/actual-weather/{date}', headers={
                            'Authorization': f'Bearer {API_KEY}'
                        }).json()

print(actual_weather)

# %% [markdown]
# #### 2. 기상 예측 조회

# %%
date = '2024-10-23'

weather_forecast = requests.get(f'https://research-api.solarkim.com/data/cmpt-2024/weather-forecast/{date}', headers={
                            'Authorization': f'Bearer {API_KEY}'
                        }).json()

print(weather_forecast)

# %% [markdown]
# #### 3. 하루전가격 조회

# %%
date = '2024-10-25'

smp_da = requests.get(f'https://research-api.solarkim.com/data/cmpt-2024/smp-da/{date}', headers={
                            'Authorization': f'Bearer {API_KEY}'
                        }).json()

print(smp_da)
# Out:
# [{'ts': 1729785600, 'smp_da': 152.17}, {'ts': 1729789200, 'smp_da': 92.23}, {'ts': 1729792800, 'smp_da': 92.23}, {'ts': 1729796400, 'smp_da': 92.1}, {'ts': 1729800000, 'smp_da': 92.23}, {'ts': 1729803600, 'smp_da': 92.43}, {'ts': 1729807200, 'smp_da': 101.06}, {'ts': 1729810800, 'smp_da': 101.28}, {'ts': 1729814400, 'smp_da': 138.32}, {'ts': 1729818000, 'smp_da': 139.24}, {'ts': 1729821600, 'smp_da': 216.99}, {'ts': 1729825200, 'smp_da': 133.16}, {'ts': 1729828800, 'smp_da': 0.0}, {'ts': 1729832400, 'smp_da': 209.55}, {'ts': 1729836000, 'smp_da': 213.08}, {'ts': 1729839600, 'smp_da': 206.86}, {'ts': 1729843200, 'smp_da': 152.32}, {'ts': 1729846800, 'smp_da': 155.17}, {'ts': 1729850400, 'smp_da': 155.03}, {'ts': 1729854000, 'smp_da': 154.78}, {'ts': 1729857600, 'smp_da': 155.92}, {'ts': 1729861200, 'smp_da': 155.03}, {'ts': 1729864800, 'smp_da': 101.02}, {'ts': 1729868400, 'smp_da': 155.92}]

# %% [markdown]
# #### 4. 실시간 임시/확정가격 조회

# %%
date = '2024-11-01'

smp_rt_rc = requests.get(f'https://research-api.solarkim.com/data/cmpt-2024/smp-rt-rc/{date}', headers={
                            'Authorization': f'Bearer {API_KEY}'
                        }).json()

print(smp_rt_rc)
# Out:
# []

# %% [markdown]
# #### 5. 제주전력시장 현황데이터(수요/공급) 조회

# %%
date = '2024-10-23'

elec_supply = requests.get(f'https://research-api.solarkim.com/data/cmpt-2024/elec-supply/{date}', headers={
                            'Authorization': f'Bearer {API_KEY}'
                        }).json()

print(elec_supply)
# Out:
# [{'ts': 1729609500, 'supply_power': 1254000.0, 'present_load': 604000.0, 'power_solar': 0.0, 'power_wind': 252669.0, 'renewable_energy_total': 261110.0, 'supply_capacity': 644000.0, 'operation_capacity': 301000.0}, {'ts': 1729609800, 'supply_power': 1260000.0, 'present_load': 594000.0, 'power_solar': 0.0, 'power_wind': 254414.0, 'renewable_energy_total': 262771.0, 'supply_capacity': 661000.0, 'operation_capacity': 313000.0}, {'ts': 1729610100, 'supply_power': 1258000.0, 'present_load': 589000.0, 'power_solar': 0.0, 'power_wind': 253042.0, 'renewable_energy_total': 261438.0, 'supply_capacity': 664000.0, 'operation_capacity': 312000.0}, {'ts': 1729610400, 'supply_power': 1245000.0, 'present_load': 583000.0, 'power_solar': 0.0, 'power_wind': 239697.0, 'renewable_energy_total': 248055.0, 'supply_capacity': 657000.0, 'operation_capacity': 310000.0}, {'ts': 1729610700, 'supply_power': 1243000.0, 'present_load': 574000.0, 'power_solar': 0.0, 'power_wind': 235746.0, 'renewable_energy_total': 244142.0, 'supply_capacity': 665000.0, 'operation_capacity': 309000.0}, {'ts': 1729611000, 'supply_power': 1242000.0, 'present_load': 574000.0, 'power_solar': 0.0, 'power_wind': 236386.0, 'renewable_energy_total': 244871.0, 'supply_capacity': 663000.0, 'operation_capacity': 315000.0}, {'ts': 1729611300, 'supply_power': 1243000.0, 'present_load': 572000.0, 'power_solar': 0.0, 'power_wind': 236885.0, 'renewable_energy_total': 245352.0, 'supply_capacity': 666000.0, 'operation_capacity': 202000.0}, {'ts': 1729611600, 'supply_power': 1244000.0, 'present_load': 568000.0, 'power_solar': 0.0, 'power_wind': 237173.0, 'renewable_energy_total': 245678.0, 'supply_capacity': 671000.0, 'operation_capacity': 205000.0}, {'ts': 1729611900, 'supply_power': 1241000.0, 'present_load': 562000.0, 'power_solar': 0.0, 'power_wind': 233773.0, 'renewable_energy_total': 242326.0, 'supply_capacity': 673000.0, 'operation_capacity': 204000.0}, {'ts': 1729612200, 'supply_power': 1236000.0, 'present_load': 562000.0, 'power_solar': 0.0, 'power_wind': 228560.0, 'renewable_energy_total': 237153.0, 'supply_capacity': 669000.0, 'operation_capacity': 204000.0}, {'ts': 1729612500, 'supply_power': 1242000.0, 'present_load': 554000.0, 'power_solar': 0.0, 'power_wind': 236059.0, 'renewable_energy_total': 244610.0, 'supply_capacity': 683000.0, 'operation_capacity': 216000.0}, {'ts': 1729612800, 'supply_power': 1239000.0, 'present_load': 547000.0, 'power_solar': 0.0, 'power_wind': 233606.0, 'renewable_energy_total': 242113.0, 'supply_capacity': 687000.0, 'operation_capacity': 218000.0}, {'ts': 1729613100, 'supply_power': 1247000.0, 'present_load': 550000.0, 'power_solar': 0.0, 'power_wind': 242554.0, 'renewable_energy_total': 251059.0, 'supply_capacity': 692000.0, 'operation_capacity': 227000.0}, {'ts': 1729613400, 'supply_power': 1244000.0, 'present_load': 543000.0, 'power_solar': 0.0, 'power_wind': 239486.0, 'renewable_energy_total': 247953.0, 'supply_capacity': 697000.0, 'operation_capacity': 230000.0}, {'ts': 1729613700, 'supply_power': 1248000.0, 'present_load': 539000.0, 'power_solar': 0.0, 'power_wind': 242720.0, 'renewable_energy_total': 251183.0, 'supply_capacity': 704000.0, 'operation_capacity': 234000.0}, {'ts': 1729614000, 'supply_power': 1246000.0, 'present_load': 542000.0, 'power_solar': 0.0, 'power_wind': 239683.0, 'renewable_energy_total': 248236.0, 'supply_capacity': 699000.0, 'operation_capacity': 222000.0}, {'ts': 1729614300, 'supply_power': 1236000.0, 'present_load': 537000.0, 'power_solar': 0.0, 'power_wind': 231929.0, 'renewable_energy_total': 240435.0, 'supply_capacity': 694000.0, 'operation_capacity': 214000.0}, {'ts': 1729614600, 'supply_power': 1238000.0, 'present_load': 534000.0, 'power_solar': 0.0, 'power_wind': 232567.0, 'renewable_energy_total': 241117.0, 'supply_capacity': 699000.0, 'operation_capacity': 219000.0}, {'ts': 1729614900, 'supply_power': 1236000.0, 'present_load': 532000.0, 'power_solar': 0.0, 'power_wind': 232660.0, 'renewable_energy_total': 24121 ...
